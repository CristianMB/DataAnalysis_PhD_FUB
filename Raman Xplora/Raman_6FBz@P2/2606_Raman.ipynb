# %% [markdown]
# **TGA Analysis**

# %%
from pathlib import Path
import pandas as pd
import matplotlib
matplotlib.use('TkAgg')  # or Qt5Agg, depending on your system
import matplotlib.pyplot as plt
import numpy as np

# Get current working directory
current_dir = Path.cwd()

# Go 2 folders up
base_dir = current_dir.parent.parent.parent

# Build the target path
target_dir = base_dir / "Measurements" / "Raman Xplora" / "CristianB"


#532Data
HFBz_532 = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/532nm/260529_6FBz_532 nm_1800gr_x10_1%_3_120_50_100.txt"))
P2_532 = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/532nm/260529_P2ReferenceSol_532 nm_1800gr_x10_1%_3_120_50_100.txt"))
F005AP_532 = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/532nm/260529_F005AP_6FBz@P2Sol_532 nm_1800gr_x10_1%_3_120_50_100.txt"))
F005LP_532 = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/532nm/260529_F005LP_6FBz@P2Sol_532 nm_1800gr_x10_1%_3_120_50_100.txt"))

#638Data
HFBz_638 = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/638nm/260529_6FBz_638 nm_1200gr_x10_1%_3_120_50_100.txt"))
P2_638 = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/638nm/260529_P2ReferenceSol_638 nm_1200gr_x10_1%_3_120_50_100.txt"))
F005AP_638 = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/638nm/260529_F005AP_6FBz@P2Sol_638 nm_1200gr_x10_1%_3_120_50_100.txt"))
F005LP_638 = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/638nm/260529_F005LP_6FBz@P2Sol_638 nm_1200gr_x10_1%_3_120_50_100.txt"))

#785Data
P2_785 = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/785nm/260529_P2ReferenceSol_785 nm_1200gr_x10_1%_3_120_50_100.txt"))
F005AP_785 = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/785nm/260529_F005AP_6FBz@P2Sol_785 nm_1200gr_x10_1%_3_120_50_100.txt"))
F005AP_785B = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/785nm/260529_F005AP_6FBz@P2Sol_785 nm_1200gr_x10_10%_3_120_50_100.txt"))
F005LP_785 = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/785nm/260529_F005LP_6FBz@P2Sol_785 nm_1200gr_x10_1%_3_120_50_100.txt"))
F005LP_785B = next(target_dir.glob("20260529_CNT_F005_6FBz@P2_phDADQ_6FBz_P2Ref/785nm/260529_AgainF005LP_6FBz@P2Sol_785 nm_1200gr_x10_1%_3_120_50_100.txt"))




df_6FBz_532 = pd.read_csv(HFBz_532, sep="\t", comment="#", header=None, encoding="latin1")
df_P2_532 = pd.read_csv(P2_532, sep="\t", comment="#", header=None, encoding="latin1")
df_F005AP_532 = pd.read_csv(F005AP_532, sep="\t", comment="#", header=None, encoding="latin1")
df_F005LP_532 = pd.read_csv(F005LP_532, sep="\t", comment="#", header=None, encoding="latin1")

df_6FBz_638 = pd.read_csv(HFBz_638, sep="\t", comment="#", header=None, encoding="latin1")
df_P2_638 = pd.read_csv(P2_638, sep="\t", comment="#", header=None, encoding="latin1")
df_F005AP_638 = pd.read_csv(F005AP_638, sep="\t", comment="#", header=None, encoding="latin1")
df_F005LP_638 = pd.read_csv(F005LP_638, sep="\t", comment="#", header=None, encoding="latin1")

df_P2_785 = pd.read_csv(P2_785, sep="\t", comment="#", header=None, encoding="latin1")
df_F005AP_785 = pd.read_csv(F005AP_785, sep="\t", comment="#", header=None, encoding="latin1")
df_F005AP_785B = pd.read_csv(F005AP_785B, sep="\t", comment="#", header=None, encoding="latin1")
df_F005LP_785 = pd.read_csv(F005LP_785, sep="\t", comment="#", header=None, encoding="latin1")
df_F005LP_785B = pd.read_csv(F005LP_785B, sep="\t", comment="#", header=None, encoding="latin1")

# %%
#CUSTOMIZATION

poster_style = {
    "figsize": (4, 4),          # poster-friendly
    "dpi": 300,                 # high resolution
    "font_size": 12,
    "title_size": 14,
    "label_size": 12,
    "legend_size": 8,
    "line_width": 1,
    "font_family": "Calibri",
    
    # Optional: define your own colors
    "colors": None  # e.g. ["red", "blue", "green"]
}

# %%
def plot_raman(data, labels=None, style=poster_style, xlim=None, ylim = None,offset=0):
    
    plt.figure(figsize=style["figsize"], dpi=style["dpi"])
    
    plt.rcParams.update({
        "font.size": style["font_size"],
        "font.family": style["font_family"]
    })
    
    colors = style["colors"]
    
    for i, df in enumerate(data):
        label = labels[i] if labels and i < len(labels) else f"Sample {i+1}"
        
        y = df.iloc[:, 1] + i * offset
        
        plt.plot(
            df.iloc[:, 0],
            y,
            label=label,
            linewidth=style["line_width"],
            color=colors[i] if colors else None
        )
        plt.scatter(df.iloc[:, 0], y, s=0.2)
    
    plt.xlabel("Raman shift (cm-1)", fontsize=style["label_size"])
    plt.ylabel("Intensity (a.u.)", fontsize=style["label_size"])
    plt.title("Raman Spectrum", fontsize=style["title_size"])
    
    if xlim:
        plt.xlim(xlim)
    if ylim:
        plt.ylim(ylim)
    plt.legend(fontsize=style["legend_size"])
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %%
DFs_532 = [
#       df_6FBz_532,
       df_P2_532,
       df_F005AP_532,
       df_F005LP_532,
       
#       df_6FBz_638,
       df_P2_638,
       df_F005AP_638,
       df_F005LP_638,

       df_P2_785,
       df_F005AP_785,
       df_F005AP_785B,
       df_F005LP_785,
       df_F005LP_785B,

       ]

DFLabels_532 = [
#       "6FBz@532",
       "P2 SWCNTs@532",
       "F005 6FBz@P2-SWCNT (AP)@532",
       "F005 6FBz@P2-SWCNT (LP)@532",

#       "6FBz@638",
       "P2 SWCNTs@638",
       "F005 6FBz@P2-SWCNT (AP)@638",
       "F005 6FBz@P2-SWCNT (LP)@638",

       "P2 SWCNTs@785",
       "F005 6FBz@P2-SWCNT (AP)@785",
       "F005 6FBz@P2-SWCNT (AP)@785 - B",
       "F005 6FBz@P2-SWCNT (LP)@785",
       "F005 6FBz@P2-SWCNT (LP)B@785 - B",
]


DFs_norm = []

for df in DFs_532:
    df_norm = df.copy()
    df_norm.iloc[:, 1] = df_norm.iloc[:, 1] / df_norm.iloc[:, 1].max()
    DFs_norm.append(df_norm)


DFs = DFs_norm

plot_raman(DFs, DFLabels_532, offset=0.15)
plot_raman(DFs, DF_labels, xlim=(120, 200), ylim=(0, 1.2), offset=0.0)
plot_raman(DFs[1:], DFLabels_532[1:], offset=0.0)
